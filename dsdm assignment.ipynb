# %%
import pandas as pd

# %%
df=pd.read_json('train_others.json')
df
# Out:
#             db_id                                              query  \
# 0             geo  SELECT city_name FROM city WHERE population  =...
# 1             geo  SELECT city_name FROM city WHERE population  =...
# 2             geo  SELECT city_name FROM city WHERE population  =...
# 3             geo  SELECT city_name FROM city WHERE population  =...
# 4             geo  SELECT city_name FROM city WHERE population  =...
# ...           ...                                                ...
# 1654  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1655  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1656  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1657  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1658  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
#
#                                              query_toks  \
# 0     [SELECT, city_name, FROM, city, WHERE, populat...
# ...

# %%
df1= pd.read_json('train_spider.json')
df1
# Out:
#                       db_id  \
# 0     department_management
# 1     department_management
# 2     department_management
# 3     department_management
# 4     department_management
# ...                     ...
# 6995        culture_company
# 6996        culture_company
# 6997        culture_company
# 6998        culture_company
# 6999        culture_company
#
#                                                   query  \
# 0            SELECT count(*) FROM head WHERE age  >  56
# 1     SELECT name ,  born_state ,  age FROM head ORD...
# 2     SELECT creation ,  name ,  budget_in_billions ...
# 3     SELECT max(budget_in_billions) ,  min(budget_i...
# 4     SELECT avg(num_employees) FROM department WHER...
# ...                                                 ...
# 6995  SELECT T1.company_name FROM culture_company AS...
# 6996  SELECT T1.title ,  T3.book_title FROM movie AS...
# 6997  SELECT T1.title ,  T3.book_title FROM movie AS...
# ...

# %%
dev = pd.read_json('dev.json')
dev
# Out:
#                        db_id  \
# 0             concert_singer
# 1             concert_singer
# 2             concert_singer
# 3             concert_singer
# 4             concert_singer
# ...                      ...
# 1029                  singer
# 1030  real_estate_properties
# 1031  real_estate_properties
# 1032  real_estate_properties
# 1033  real_estate_properties
#
#                                                   query  \
# 0                           SELECT count(*) FROM singer
# 1                           SELECT count(*) FROM singer
# 2     SELECT name ,  country ,  age FROM singer ORDE...
# 3     SELECT name ,  country ,  age FROM singer ORDE...
# 4     SELECT avg(age) ,  min(age) ,  max(age) FROM s...
# ...                                                 ...
# 1029  SELECT Citizenship FROM singer WHERE Birth_Yea...
# 1030      SELECT count(*) FROM Other_Available_Features
# 1031  SELECT T2.feature_type_name FROM Other_Availab...
# ...

# %%
dev['question'].value_counts()
# Out:
# In which years cars were produced weighing no less than 3000 and no more than 4000 ?                        1
# Show ids of all students who do not have any friends.                                                       1
# What is the episode for the TV series named "Sky Radio"?                                                    1
# Find the cities that have more than one employee under age 30.                                              1
# What is the feature type name of feature AirCon?                                                            1
#                                                                                                            ..
# List the first name of all the professionals along with the description of the treatment they have done.    1
# What are the number of concerts that occurred in the stadium with the largest capacity ?                    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1659 entries, 0 to 1658
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   db_id                1659 non-null   object
#  1   query                1659 non-null   object
#  2   query_toks           1659 non-null   object
#  3   query_toks_no_value  1659 non-null   object
#  4   question             1659 non-null   object
#  5   question_toks        1659 non-null   object
#  6   sql                  1659 non-null   object
# dtypes: object(7)
# memory usage: 90.9+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   db_id                7000 non-null   object
#  1   query                7000 non-null   object
#  2   query_toks           7000 non-null   object
#  3   query_toks_no_value  7000 non-null   object
#  4   question             7000 non-null   object
#  5   question_toks        7000 non-null   object
#  6   sql                  7000 non-null   object
# dtypes: object(7)
# memory usage: 382.9+ KB

# %%
dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   db_id                1034 non-null   object
#  1   query                1034 non-null   object
#  2   query_toks           1034 non-null   object
#  3   query_toks_no_value  1034 non-null   object
#  4   question             1034 non-null   object
#  5   question_toks        1034 non-null   object
#  6   sql                  1034 non-null   object
# dtypes: object(7)
# memory usage: 56.7+ KB

# %%
import string

unwanted = string.punctuation + string.whitespace
print(unwanted)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# This helped me extract '10' from '10+ years'.

dev.question = dev.question.str.strip(unwanted)

# %%
dev
# Out:
#                        db_id  \
# 0             concert_singer
# 1             concert_singer
# 2             concert_singer
# 3             concert_singer
# 4             concert_singer
# ...                      ...
# 1029                  singer
# 1030  real_estate_properties
# 1031  real_estate_properties
# 1032  real_estate_properties
# 1033  real_estate_properties
#
#                                                   query  \
# 0                           SELECT count(*) FROM singer
# 1                           SELECT count(*) FROM singer
# 2     SELECT name ,  country ,  age FROM singer ORDE...
# 3     SELECT name ,  country ,  age FROM singer ORDE...
# 4     SELECT avg(age) ,  min(age) ,  max(age) FROM s...
# ...                                                 ...
# 1029  SELECT Citizenship FROM singer WHERE Birth_Yea...
# 1030      SELECT count(*) FROM Other_Available_Features
# 1031  SELECT T2.feature_type_name FROM Other_Availab...
# ...

# %%
dev.question = dev.question.str.lower()

# %%
dev
# Out:
#                        db_id  \
# 0             concert_singer
# 1             concert_singer
# 2             concert_singer
# 3             concert_singer
# 4             concert_singer
# ...                      ...
# 1029                  singer
# 1030  real_estate_properties
# 1031  real_estate_properties
# 1032  real_estate_properties
# 1033  real_estate_properties
#
#                                                   query  \
# 0                           SELECT count(*) FROM singer
# 1                           SELECT count(*) FROM singer
# 2     SELECT name ,  country ,  age FROM singer ORDE...
# 3     SELECT name ,  country ,  age FROM singer ORDE...
# 4     SELECT avg(age) ,  min(age) ,  max(age) FROM s...
# ...                                                 ...
# 1029  SELECT Citizenship FROM singer WHERE Birth_Yea...
# 1030      SELECT count(*) FROM Other_Available_Features
# 1031  SELECT T2.feature_type_name FROM Other_Availab...
# ...

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PRATYAY\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PRATYAY\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PRATYAY\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
stopwords = stopwords.words('english')

# %%
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
from nltk.corpus import stopwords
en_stops = set(stopwords.words('english'))

all_words = ['How', 'many', 'heads', 'of', 'the', 'departments', 'are', 'older', 'the']
for word in all_words: 
    if word not in en_stops:
        print(word)
# Out:
# How
# many
# heads
# departments
# older

# %%
from nltk.corpus import stopwords
en_stops = set(stopwords.words('english'))

all_words = ['How', 'many', 'singer', 'do', 'we', 'have']
for word in all_words: 
    if word not in en_stops:
        print(word)
# Out:
# How
# many
# singer

# %%
from nltk.corpus import stopwords
en_stops = set(stopwords.words('english'))

all_words = ['what','is','the','total','no','of','singer']
for word in all_words: 
    if word not in en_stops:
        print(word)
# Out:
# total
# singer

# %%
from nltk.corpus import stopwords
en_stops = set(stopwords.words('english'))

all_words = ['show','name','country','age','for','all', 'singer','ordere']
for word in all_words: 
    if word not in en_stops:
        print(word)
# Out:
# show
# name
# country
# age
# singer
# ordere

# %%
import string

unwanted = string.punctuation + string.whitespace
print(unwanted)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
df.question = dev.question.str.strip(unwanted)
df
# Out:
#             db_id                                              query  \
# 0             geo  SELECT city_name FROM city WHERE population  =...
# 1             geo  SELECT city_name FROM city WHERE population  =...
# 2             geo  SELECT city_name FROM city WHERE population  =...
# 3             geo  SELECT city_name FROM city WHERE population  =...
# 4             geo  SELECT city_name FROM city WHERE population  =...
# ...           ...                                                ...
# 1654  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1655  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1656  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1657  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1658  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
#
#                                              query_toks  \
# 0     [SELECT, city_name, FROM, city, WHERE, populat...
# ...

# %%
df.question = df.question.str.lower()
df
# Out:
#             db_id                                              query  \
# 0             geo  SELECT city_name FROM city WHERE population  =...
# 1             geo  SELECT city_name FROM city WHERE population  =...
# 2             geo  SELECT city_name FROM city WHERE population  =...
# 3             geo  SELECT city_name FROM city WHERE population  =...
# 4             geo  SELECT city_name FROM city WHERE population  =...
# ...           ...                                                ...
# 1654  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1655  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1656  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1657  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1658  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
#
#                                              query_toks  \
# 0     [SELECT, city_name, FROM, city, WHERE, populat...
# ...

# %%
for i,j in df['question'].mode().iteritems():
    max_freq=str(j)
df['question'].fillna(max_freq, inplace = True)
df
# Out:
#             db_id                                              query  \
# 0             geo  SELECT city_name FROM city WHERE population  =...
# 1             geo  SELECT city_name FROM city WHERE population  =...
# 2             geo  SELECT city_name FROM city WHERE population  =...
# 3             geo  SELECT city_name FROM city WHERE population  =...
# 4             geo  SELECT city_name FROM city WHERE population  =...
# ...           ...                                                ...
# 1654  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1655  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1656  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1657  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1658  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
#
#                                              query_toks  \
# 0     [SELECT, city_name, FROM, city, WHERE, populat...
# ...

# %%
import string

unwanted = string.punctuation + string.whitespace
print(unwanted)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
df1.question = dev.question.str.strip(unwanted)
df1
# Out:
#                       db_id  \
# 0     department_management
# 1     department_management
# 2     department_management
# 3     department_management
# 4     department_management
# ...                     ...
# 6995        culture_company
# 6996        culture_company
# 6997        culture_company
# 6998        culture_company
# 6999        culture_company
#
#                                                   query  \
# 0            SELECT count(*) FROM head WHERE age  >  56
# 1     SELECT name ,  born_state ,  age FROM head ORD...
# 2     SELECT creation ,  name ,  budget_in_billions ...
# 3     SELECT max(budget_in_billions) ,  min(budget_i...
# 4     SELECT avg(num_employees) FROM department WHER...
# ...                                                 ...
# 6995  SELECT T1.company_name FROM culture_company AS...
# 6996  SELECT T1.title ,  T3.book_title FROM movie AS...
# 6997  SELECT T1.title ,  T3.book_title FROM movie AS...
# ...

# %%
df1.question = df.question.str.lower()
df1
# Out:
#                       db_id  \
# 0     department_management
# 1     department_management
# 2     department_management
# 3     department_management
# 4     department_management
# ...                     ...
# 6995        culture_company
# 6996        culture_company
# 6997        culture_company
# 6998        culture_company
# 6999        culture_company
#
#                                                   query  \
# 0            SELECT count(*) FROM head WHERE age  >  56
# 1     SELECT name ,  born_state ,  age FROM head ORD...
# 2     SELECT creation ,  name ,  budget_in_billions ...
# 3     SELECT max(budget_in_billions) ,  min(budget_i...
# 4     SELECT avg(num_employees) FROM department WHER...
# ...                                                 ...
# 6995  SELECT T1.company_name FROM culture_company AS...
# 6996  SELECT T1.title ,  T3.book_title FROM movie AS...
# 6997  SELECT T1.title ,  T3.book_title FROM movie AS...
# ...

# %%
for i,j in df['question'].mode().iteritems():
    max_freq=str(j)
df['question'].fillna(max_freq, inplace = True)
df
# Out:
#             db_id                                              query  \
# 0             geo  SELECT city_name FROM city WHERE population  =...
# 1             geo  SELECT city_name FROM city WHERE population  =...
# 2             geo  SELECT city_name FROM city WHERE population  =...
# 3             geo  SELECT city_name FROM city WHERE population  =...
# 4             geo  SELECT city_name FROM city WHERE population  =...
# ...           ...                                                ...
# 1654  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1655  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1656  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1657  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1658  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
#
#                                              query_toks  \
# 0     [SELECT, city_name, FROM, city, WHERE, populat...
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
plt.hist(dev['question']);

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer = CountVectorizer()
feature_vector = count_vectorizer.fit(dev)
features = feature_vector.get_feature_names()
print("total no of features:",len(features))
# Out:
# total no of features: 7

# %%
dev_features = count_vectorizer.transform(dev)
type(dev_features)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
dev_features.shape
# Out:
# (7, 7)

# %%
dev_features.getnnz()
# Out:
# 7

# %%
print("Density of matrix:",dev_features.getnnz()*100/(dev_features.shape[0]*dev_features.shape[1]))
# Out:
# Density of matrix: 14.285714285714286

# %%
import pandas as pd
dev_df = pd.DataFrame(dev_features.todense())
dev_df.columns = features

# %%
import numpy as np
import pandas as pd
features_counts = np.sum(dev_features.toarray, axis=0)
feature_counts_df = pd.DataFrame(dict(features=features,counts=features_counts))

# %%
len(feature_counts_df[feature_counts_df.counts == 1])
# Out:
# 0

# %%
count_vectorizer = CountVectorizer(max_features = 1000)
feature_vector = count_vectorizer.fit(dev)
features = feature_vector.get_feature_names()
dev_features = count_vectorizer.transform(dev)
features_counts = np.sum(dev_features.toarray(), axis=0)
feature_counts = pd.DataFrame(dict(features=features , counts = features_counts))

# %%
feature_counts.sort_values('counts', ascending=False)[0:15]
# Out:
#               features  counts
# 0                db_id       1
# 1                query       1
# 2           query_toks       1
# 3  query_toks_no_value       1
# 4             question       1
# 5        question_toks       1
# 6                  sql       1

# %%
import string

unwanted =  string.whitespace
print(unwanted)

# %%
dev.query = dev.question.str.strip(unwanted)

# %%
dev
# Out:
#                        db_id  \
# 0             concert_singer
# 1             concert_singer
# 2             concert_singer
# 3             concert_singer
# 4             concert_singer
# ...                      ...
# 1029                  singer
# 1030  real_estate_properties
# 1031  real_estate_properties
# 1032  real_estate_properties
# 1033  real_estate_properties
#
#                                                   query  \
# 0                           SELECT count(*) FROM singer
# 1                           SELECT count(*) FROM singer
# 2     SELECT name ,  country ,  age FROM singer ORDE...
# 3     SELECT name ,  country ,  age FROM singer ORDE...
# 4     SELECT avg(age) ,  min(age) ,  max(age) FROM s...
# ...                                                 ...
# 1029  SELECT Citizenship FROM singer WHERE Birth_Yea...
# 1030      SELECT count(*) FROM Other_Available_Features
# 1031  SELECT T2.feature_type_name FROM Other_Availab...
# ...

# %%
dev.query = dev.query.str.lower()
dev
# Out:
#                        db_id  \
# 0             concert_singer
# 1             concert_singer
# 2             concert_singer
# 3             concert_singer
# 4             concert_singer
# ...                      ...
# 1029                  singer
# 1030  real_estate_properties
# 1031  real_estate_properties
# 1032  real_estate_properties
# 1033  real_estate_properties
#
#                                                   query  \
# 0                           SELECT count(*) FROM singer
# 1                           SELECT count(*) FROM singer
# 2     SELECT name ,  country ,  age FROM singer ORDE...
# 3     SELECT name ,  country ,  age FROM singer ORDE...
# 4     SELECT avg(age) ,  min(age) ,  max(age) FROM s...
# ...                                                 ...
# 1029  SELECT Citizenship FROM singer WHERE Birth_Yea...
# 1030      SELECT count(*) FROM Other_Available_Features
# 1031  SELECT T2.feature_type_name FROM Other_Availab...
# ...
